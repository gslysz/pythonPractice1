# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

filepath1 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_31_orig.txt"
data1 = pd.read_csv(filepath1)

filepath2 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_31_decompressed.txt"
data2 = pd.read_csv(filepath2)

fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(14,6))

axes[0].plot(data1)
axes[0].set_title('Original')
axes[0].set_xlim(0,250)

ylim = axes[0].get_ylim()
xlim = axes[0].get_xlim()

axes[1].plot(data2)
axes[1].set_title('SimpleDelta')
axes[1].set_ylim(ylim[0], ylim[1])
axes[1].set_xlim(xlim[0], xlim[1])
# Out:
# (0.0, 250.0)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

filepath1 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_32_orig.txt"
data1 = pd.read_csv(filepath1)

filepath2 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_32_decompressed.txt"
data2 = pd.read_csv(filepath2)

fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(14,6))

axes[0].plot(data1)
axes[0].set_title('Original')
axes[0].set_xlim(0,250)

ylim = axes[0].get_ylim()
xlim = axes[0].get_xlim()

axes[1].plot(data2)
axes[1].set_title('SimpleDelta')
axes[1].set_ylim(ylim[0], ylim[1])
axes[1].set_xlim(xlim[0], xlim[1])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-053d89d4fa7a> in <module>
#       4
#       5 filepath1 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_32_orig.txt"
# ----> 6 data1 = pd.read_csv(filepath1)
#       7
#       8 filepath2 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_32_decompressed.txt"
#
# ...

# %%
def doPlot(filepath1, filepath2):
    data1 = pd.read_csv(filepath1)
    data2 = pd.read_csv(filepath2)
    fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(14,6))

    axes[0].plot(data1)
    axes[0].set_title('Original')
    axes[0].set_xlim(0,200)
    

    ylim = axes[0].get_ylim()
    xlim = axes[0].get_xlim()

    axes[1].plot(data2)
    axes[1].set_title('SimpleDelta')
    axes[1].set_ylim(ylim[0], ylim[1])
    axes[1].set_xlim(xlim[0], xlim[1])

# %%
filepath1 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_31_orig.txt"
filepath2 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_31_decompressed.txt"
doPlot(filepath1,filepath2)
filepath1 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_32_orig.txt"
filepath2 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_32_decompressed.txt"
doPlot(filepath1,filepath2)
filepath1 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_33_orig.txt"
filepath2 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_33_decompressed.txt"
doPlot(filepath1,filepath2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e15ef00858ef> in <module>
#       1 filepath1 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_31_orig.txt"
#       2 filepath2 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_31_decompressed.txt"
# ----> 3 doPlot(filepath1,filepath2)
#       4 filepath1 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_32_orig.txt"
#       5 filepath2 = r"C:\ProgramData\Cadwell\Temp\Output\jimpeak_00_01_32_decompressed.txt"
#
# <ipython-input-4-7b6c6a92a23f> in doPlot(filepath1, filepath2)
#       1 def doPlot(filepath1, filepath2):
# ----> 2     data1 = pd.read_csv(filepath1)
#       3     data2 = pd.read_csv(filepath2)
#       4     fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(14,6))
#       5
#
# ...
